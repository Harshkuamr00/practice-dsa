# %% [markdown]
# ## lets practice some of the methods, first we implement simple hash map after practice some of the methods

# %%
# code 
class table:
    def __init__(self):
        self.table={}

    ## insert
    def insert(self,key,value):
        self.table[key]=value

    def update(self,key,value):
        if key in self.table:
            self.table[key]=value

        else:
            print(f" the {key} is not found try hard nigga")

    def find(self,key):
        return self.table[key]

    def delete(self,key):
        if key in self.table:
            self.table[key]=value
        else:
            print(f" the {key} is not found")

    ## list all
    def list_all(self):
        return self.table.items()

    ## check is exit or not
    def contains(self,key):
        if key in self.table:
            return True
        else:
            return False
    ## get all key only

    def get_key(self):
        for i in self.table:
            return self.table.keys()

    ## merge two hash table 
    def merge(self,m):
        for key, value in m.list_all():
            self.table[key]=value

    ## find keys with given value
    def find_keys(self,value):
        if value in self.table:
            keys=[k for k,v in self.table.items() if v == value]
            print(keys)
        else:
            print("think more harder nigga")

# %%
h1=table()
h1.insert("a", 1)
h1.insert("b", 2)

h2=table()
h2.insert("b", 3)  # Overwrites 'b' in ht1
h2.insert("c", 4)

# %%
h1.merge(h2)

# %%
h1.list_all()
# Out:
# dict_items([('a', 1), ('b', 3), ('c', 4)])

# %%
ds={
    "sdf":2,
    "dfd":3,
    "dg":4
}

# %%
ds.items()
# Out:
# dict_items([('sdf', 2), ('dfd', 3), ('dg', 4)])

# %%
ds.keys()
# Out:
# dict_keys(['sdf', 'dfd', 'dg'])

# %%
ds[
