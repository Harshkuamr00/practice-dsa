# %% [markdown]
# ## Linkedlist

# %% [markdown]
# Its a data sturcture linear , stores the data sequancially and individual items are called nodes and connected with each other using links.

# %%
## example how to create linkedlist data sturcture
class node():
    def __init__(self):
        self.data=0

# %%
node1=node()

# %% [markdown]
# Internally we create a empty object, stores the reference to the empty object in an temporary variable called self, calls the __init__ function

# %%
node1

# %%
node1.data

# %% [markdown]
# now we create one more node with value 10

# %%
node2=node()

# %%
node2.data=100

# %%
node2.data

# %% [markdown]
# likewise we create some more nodes

# %%
node3=node()
node3.data=200

# %%
node4=node()
node4.data=300

# %%
list=[node1.data,node2.data,node3.data,node4.data]

# %%
list

# %% [markdown]
# this is okay but easier way to do it

# %%
class Node():
    def __init__(self,num):
        self.data=num
        self.next=None

# %%
node1=Node(0)
node2=Node(100)
node3=Node(200)
node4=Node(300)

# %%
list=[node1.data,node2.data,node3.data,node4.data]

# %%
list

# %% [markdown]
# ### Now we ready to define our class in linked list

# %%
class Linkedlist():
    def __init__(self):
        self.head=None

# %%
list1=Linkedlist()
list1.head=Node(10)
list1.head.next=Node(20)
list1.head.next.next=Node(30)

# %%
list1.head.data, list1.head.next.data, list1.head.next.next.data

# %% [markdown]
# now we know the process lets implement with couple more arguments

# %%
class NNode():
    # data and next property of linkedlist
    def __init__(self,nums):
        self.data=nums
        self.next=None
class LinkedList():
    # we initize the head node with none value with simple method
    def __init__(self):
        self.head=None
# define method or function to add the value in linkedlist
    def add(self,nums):
        if self.head == None:
            self.head= NNode(nums)
        else:
            current_node=self.head
            while current_node.next != None:
                current_node = current_node.next

            current_node.next= NNode(nums)

# %%
list2=LinkedList()
list2.add(2)
list2.add(4)
list2.add(5)

# %%
list2

# %%
list2.head.data,list2.head.next.data,list2.head.next.next.data

# %% [markdown]
# #### lets add the method for print the linkedlist

# %%
class node():
    def __init__(self,num):
        self.data=num
        self.next=None

class linkedlist():
    def __init__(self):
        self.head=None

    # initize the method to insert or add the value in linked list

    def add(self,num):
        if self.head is None:
            self.head=node(num)
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=node(num)

    # initzie the method that print value in linked list
    def printlist(self):
        current=self.head
        while current != None:
            print(current.data)
            current=current.next

# %%
list3=linkedlist()
list3.add(1)
list3.add(2)
list3.add(3)
list3.add(4)
list3.add(5)

# %%
list3.printlist()
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ooo oyye oo yuyy

# %% [markdown]
# now lets do with more couples of arguments

# %%
class node():
    def __init__(self,num):
        self.data=num
        self.next=None

class list():
    def __init__(self):
        self.head=None

    ## add method
    def add(self,num):
        if self.head is None:
            self.head=node(num)
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=node(num)

    ## show method to get all elements in linkedlist
    def show(self):
        current=self.head

        while current != None:
            print(current.data)
            current=current.next

    ## find lenght of the linkedlist
    def length(self):
        result=0
        current=self.head
        while current is not None:
            result+=1
            current=current.next
        return result

    ## find the position of element in linkedlist
    def find(self,position):
        i=0
        current= self.head

        while current != None:
            if i == position:
                return current.data
            current= current.next
            i+=1
        return None

    ## reverse linkedlist

# %%
list4=list()
list4.add(1)
list4.add(2)
list4.add(3)
list4.add(4)
list4.add(5)
list4.add(6)
list4.add(7)
list4.add(8)
list4.add(0)

# %%
list4.length()
# Out:
# 9

# %%
list4.find(4)
# Out:
# 5

# %%
list4.show()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 0
